# %% [markdown]
# # Binder Magic Demo
#
# Example of using Binder magic to launch a MyBinder container from Github and then access it from a notebook running the magic.
#
# Install from the Github repo:
#
# `pip install --upgrade git+https://github.com/innovationOUtside/ipython_binder_magic.git`
#
# The magic can then be loaded as:
#
# `%load_ext binder_magic`
#
# or
#
# `%reload_ext binder_magic`

# %%
# %reload_ext binder_magic

# %% [markdown]
# The MyBinder connection should be initiated by calling the `%binder` line magic with a `-r` argument containing the name of the Gituhb repository you want to use as the Binder target.

# %%
# %binder -r https://github.com/ouseful-demos/ordo
# Out:
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# {'message': 'Launching server...\n', 'phase': 'launching'}
# wss://hub.gke.mybinder.org/user/ouseful-demos-ordo-oezw7j19/api/kernels/6c138eb5-117e-462d-95a3-12fc75d5041d/channels?token=IQcrTEbNQ3ybaLrsA0Qm3A

# %% [markdown]
# Once the Binder image is running, we can start to run commands against it using `%%binder` cell magic:

# %%
# %%binder
# !ls
# Out:
# MANIFEST.in  ordo  README.ipynb  README.md  setup.cfg  setup.py

# %%
# %%binder
# a=1

# %%
# %%binder
# a
# Out:
# 1

# %%
# %%binder
# !pip install pandas
# import pandas as pd
# pd.DataFrame({'a':[1,2], 'b':['foo','bar']})
# Out:
# Collecting pandas
#   Downloading https://files.pythonhosted.org/packages/63/e0/a1b39cdcb2c391f087a1538bc8a6d62a82d0439693192aef541d7b123769/pandas-0.25.3-cp37-cp37m-manylinux1_x86_64.whl (10.4MB)
#      |                                | 30kB 3.2MB/s eta 0:00:04
#      |██▊                             | 870kB 3.4MB/s eta 0:00:03
#      |███████████▏                    | 3.6MB 3.4MB/s eta 0:00:02
#      |████████████████                | 5.2MB 3.4MB/s eta 0:00:02
#      |█████████████████████████       | 8.2MB 3.4MB/s eta 0:00:01
#      |██████████████████████████████▎ | 9.9MB 3.4MB/s eta 0:00:01
#      |████████████████████████████████| 10.4MB 3.4MB/s
# Collecting numpy>=1.13.3 (from pandas)
#   Downloading https://files.pythonhosted.org/packages/9b/af/4fc72f9d38e43b092e91e5b8cb9956d25b2e3ff8c75aed95df5569e4734e/numpy-1.17.4-cp37-cp37m-manylinux1_x86_64.whl (20.0MB)
#      |█▌                              | 942kB 27.2MB/s eta 0:00:01
#      |██████▉                         | 4.3MB 27.2MB/s eta 0:00:01
#      |███████████▋                    | 7.3MB 27.2MB/s eta 0:00:01
#      |█████████████████▊              | 11.1MB 27.2MB/s eta 0:00:01
#      |████████████████████▋           | 12.9MB 27.2MB/s eta 0:00:01
#      |█████████████████████████       | 15.7MB 27.2MB/s eta 0:00:01
#      |███████████████████████████▉    | 17.4MB 27.2MB/s eta 0:00:01
#      |████████████████████████████████| 20.0MB 27.2MB/s eta 0:00:01
#      |████████████████████████████████| 20.0MB 27.2MB/s
# Collecting pytz>=2017.2 (from pandas)
#   Downloading https://files.pythonhosted.org/packages/e7/f9/f0b53f88060247251bf481fa6ea62cd0d25bf1b11a87888e53ce5b7c8ad2/pytz-2019.3-py2.py3-none-any.whl (509kB)
#      |█████████                       | 143kB 39.6MB/s eta 0:00:01
#      |████████████████████████████████| 512kB 39.6MB/s
# Requirement already satisfied: python-dateutil>=2.6.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2.8.0)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.12.0)
# Installing collected packages: numpy, pytz, pandas
# Successfully installed numpy-1.17.4 pandas-0.25.3 pytz-2019.3
#    a    b
# 0  1  foo
# 1  2  bar

# %%
# %%binder
# print('a')
# Out:
# /usr/local/lib/python3.7/site-packages/binder_magic/binder_magic.py:136: UserWarning: Binder kernel connection seems to have died...
#   warnings.warn('Binder kernel connection seems to have died...')

# %% [markdown]
# Note that whilst a heartbeat is sent back to the Binder kernel every 30s, the connection seems to die quite quickly (after about 2 minutes of inactivity?). A warning should be raised if the connection is detected to have died.
#
# I wonder if we can con the Binder instance into thinking something is alive by creating a dummy notebook / kernel and writing adding a new cell to it in the background every 30s or so, so that the Binder container knows it's still being used (?!) and doesn't time out so quickly...?
